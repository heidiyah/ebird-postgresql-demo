# %%
import pandas as pd
import numpy as np
import matplotlib as mpl

# %%
filepath = r"Z:\ebd_relJun-2025\one_thou_rows.txt"

df_sample = pd.read_csv(filepath, sep='\t')#, nrows=100)
# pd.set_option('display.max_columns', None)
df_sample.head()
# Out:
#                          GLOBAL UNIQUE IDENTIFIER            LAST EDITED DATE  \
# 0  URN:CornellLabOfOrnithology:EBIRD:OBS121783369         2016-03-24 00:09:03
# 1  URN:CornellLabOfOrnithology:EBIRD:OBS976192817  2025-04-30 10:28:33.168809
# 2  URN:CornellLabOfOrnithology:EBIRD:OBS977984816  2024-03-16 11:58:20.874704
# 3  URN:CornellLabOfOrnithology:EBIRD:OBS118998193  2022-10-21 18:43:43.606827
# 4  URN:CornellLabOfOrnithology:EBIRD:OBS111345171     2021-04-01 07:23:50.501
#
#    TAXONOMIC ORDER CATEGORY  TAXON CONCEPT ID             COMMON NAME  \
# 0             6339  species  avibase-2F5DF476        Pigeon Guillemot
# 1             5806  species  avibase-C4EC6263   White-crowned Lapwing
# 2             8249  species  avibase-06D9A2C8              Black Kite
# 3             6854  species  avibase-7E022378             Common Loon
# 4            32919  species  avibase-39BD9FF2  White-throated Sparrow
#
# ...

# %%
# df_sample.info()

# %%
# df_sample.dtypes

# %%
col_list = df_sample.columns
print(col_list)
# Out:
# Index(['GLOBAL UNIQUE IDENTIFIER', 'LAST EDITED DATE', 'TAXONOMIC ORDER',
#        'CATEGORY', 'TAXON CONCEPT ID', 'COMMON NAME', 'SCIENTIFIC NAME',
#        'SUBSPECIES COMMON NAME', 'SUBSPECIES SCIENTIFIC NAME', 'EXOTIC CODE',
#        'OBSERVATION COUNT', 'BREEDING CODE', 'BREEDING CATEGORY',
#        'BEHAVIOR CODE', 'AGE/SEX', 'COUNTRY', 'COUNTRY CODE', 'STATE',
#        'STATE CODE', 'COUNTY', 'COUNTY CODE', 'IBA CODE', 'BCR CODE',
#        'USFWS CODE', 'ATLAS BLOCK', 'LOCALITY', 'LOCALITY ID', 'LOCALITY TYPE',
#        'LATITUDE', 'LONGITUDE', 'OBSERVATION DATE',
#        'TIME OBSERVATIONS STARTED', 'OBSERVER ID', 'OBSERVER ORCID ID',
#        'SAMPLING EVENT IDENTIFIER', 'OBSERVATION TYPE', 'PROTOCOL NAME',
#        'PROTOCOL CODE', 'PROJECT NAMES', 'PROJECT IDENTIFIERS',
#        'DURATION MINUTES', 'EFFORT DISTANCE KM', 'EFFORT AREA HA',
#        'NUMBER OBSERVERS', 'ALL SPECIES REPORTED', 'GROUP IDENTIFIER',
# ...

# %%
for i in range(len(col_list)):
    s = col_list[i].replace(' ','_')
    s = s.replace('/','_')
    print(f'{i+1}', s)
# Out:
# 1 GLOBAL_UNIQUE_IDENTIFIER
# 2 LAST_EDITED_DATE
# 3 TAXONOMIC_ORDER
# 4 CATEGORY
# 5 TAXON_CONCEPT_ID
# 6 COMMON_NAME
# 7 SCIENTIFIC_NAME
# 8 SUBSPECIES_COMMON_NAME
# 9 SUBSPECIES_SCIENTIFIC_NAME
# 10 EXOTIC_CODE
# 11 OBSERVATION_COUNT
# 12 BREEDING_CODE
# 13 BREEDING_CATEGORY
# 14 BEHAVIOR_CODE
# 15 AGE_SEX
# 16 COUNTRY
# 17 COUNTRY_CODE
# 18 STATE
# 19 STATE_CODE
# 20 COUNTY
# 21 COUNTY_CODE
# 22 IBA_CODE
# 23 BCR_CODE
# 24 USFWS_CODE
# 25 ATLAS_BLOCK
# 26 LOCALITY
# 27 LOCALITY_ID
# 28 LOCALITY_TYPE
# 29 LATITUDE
# 30 LONGITUDE
# 31 OBSERVATION_DATE
# 32 TIME_OBSERVATIONS_STARTED
# 33 OBSERVER_ID
# 34 OBSERVER_ORCID_ID
# 35 SAMPLING_EVENT_IDENTIFIER
# 36 OBSERVATION_TYPE
# 37 PROTOCOL_NAME
# 38 PROTOCOL_CODE
# 39 PROJECT_NAMES
# 40 PROJECT_IDENTIFIERS
# 41 DURATION_MINUTES
# 42 EFFORT_DISTANCE_KM
# 43 EFFORT_AREA_HA
# 44 NUMBER_OBSERVERS
# 45 ALL_SPECIES_REPORTED
# 46 GROUP_IDENTIFIER
# 47 HAS_MEDIA
# 48 APPROVED
# 49 REVIEWED
# 50 REASON
# 51 CHECKLIST_COMMENTS
# ...
